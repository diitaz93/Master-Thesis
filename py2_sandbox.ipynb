# %%
from __future__ import division
from __future__ import print_function
from operator import itemgetter
from itertools import combinations, chain
import argparse
import time
import os
import tensorflow as tf
import numpy as np
import networkx as nx
import scipy.sparse as sp
from sklearn import metrics
import pandas as pd
import psutil
import pickle
from decagon.deep.optimizer import DecagonOptimizer
from decagon.deep.model import DecagonModel
from decagon.deep.minibatch import EdgeMinibatchIterator
from decagon.deep import layers
from decagon.utility import rank_metrics, preprocessing

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = layers.GraphConvolutionMulti(5,5,sp.identity(5))

# %%
df = pd.read_csv("data/original_data/bio-decagon-effectcategories.csv")

# %%
df
# Out:
#     Side Effect            Side Effect Name  \
# 0      C0017152        gastric inflammation
# 1      C0027858                     neuroma
# 2      C0041466                     Typhoid
# 3      C0032807    Post thrombotic syndrome
# 4      C0033860                   psoriasis
# 5      C0259749        autonomic neuropathy
# 6      C0349231                      phobia
# 7      C0027726          nephrotic syndrome
# 8      C0024437   macula lutea degeneration
# 9      C0024312       Lymphocytes decreased
# 10     C0020635             hypopituitarism
# 11     C0002878          haemolytic anaemia
# 12     C0003873        Arthritis rheumatoid
# 13     C0003872         psoriatic arthritis
# 14     C0002871                     anaemia
# 15     C0030446              adynamic ileus
# 16     C0002874             Anemia aplastic
# 17     C0029429             osteochondrosis
# 18     C0019693                 HIV disease
# 19     C0038013      ankylosing spondylitis
# 20     C0018916                 haemangioma
# 21     C0038019                 spondylosis
# 22     C0008449            chondrodystrophy
# 23     C0003486             aortic aneurysm
# 24     C0009768    bacterial conjunctivitis
# 25     C0004030               aspergillosis
# 26     C0002170                    alopecia
# 27     C0009763              conjunctivitis
# 28     C0031350     pharyngeal inflammation
# 29     C0476089          Endometrial cancer
# ..          ...                         ...
# 531    C0038358               gastric ulcer
# 532    C0018817        atrial septal defect
# 533    C0021390  inflammatory bowel disease
# 534    C0039503                  Tendinitis
# 535    C0006144                 Breast cyst
# 536    C0006145             Breast disorder
# 537    C0015645                   fasciitis
# 538    C0152020              gastric stasis
# 539    C0042267                    Colpitis
# 540    C0031039        pericardial effusion
# 541    C0152025              polyneuropathy
# 542    C0031036        periarteritis nodosa
# 543    C0018418               gynaecomastia
# 544    C0221244                    dandruff
# 545    C0002994                  angioedema
# 546    C0001126      renal tubular acidosis
# 547    C0002622                     Amnesia
# 548    C0014518                       Lyell
# 549    C0162678           neurofibromatosis
# 550    C0020555              hypertrichosis
# 551    C0005695            Bladder Neoplasm
# 552    C0020550             hyperthyroidism
# 553    C0014390                   entropion
# 554    C0017536                  giardiasis
# 555    C0029882                otitis media
# 556    C0001816                     agnosia
# 557    C0302592     carcinoma of the cervix
# 558    C0270629            epidural abscess
# 559    C0038220          status epilepticus
# 560    C0042996                    vulvitis
#
#                                Disease Class
# 0            gastrointestinal system disease
# 1                            benign neoplasm
# 2               bacterial infectious disease
# 3              cardiovascular system disease
# 4               integumentary system disease
# 5                     nervous system disease
# 6                         cognitive disorder
# 7                     urinary system disease
# 8                     nervous system disease
# 9               hematopoietic system disease
# 10                  endocrine system disease
# 11              hematopoietic system disease
# 12            musculoskeletal system disease
# 13                       psoriatic arthritis
# 14              hematopoietic system disease
# 15           gastrointestinal system disease
# 16             hematopoietic system diseases
# 17            musculoskeletal system disease
# 18                  viral infectious disease
# 19            musculoskeletal system disease
# 20                           benign neoplasm
# 21            musculoskeletal system disease
# 22            musculoskeletal system disease
# 23             cardiovascular system disease
# 24                    nervous system disease
# 25                 fungal infectious disease
# 26              integumentary system disease
# 27                    nervous system disease
# 28                respiratory system disease
# 29                                    cancer
# ..                                       ...
# 531          gastrointestinal system disease
# 532            cardiovascular system disease
# 533          gastrointestinal system disease
# 534           musculoskeletal system disease
# 535                          benign neoplasm
# 536                         thoracic disease
# 537           musculoskeletal system disease
# 538          gastrointestinal system disease
# 539              reproductive system disease
# 540            cardiovascular system disease
# 541                   nervous system disease
# 542            cardiovascular system disease
# 543                 endocrine system disease
# 544             integumentary system disease
# 545             integumentary system disease
# 546                   urinary system disease
# 547                       cognitive disorder
# 548             integumentary system disease
# 549                        monogenic disease
# 550             integumentary system disease
# 551                                   cancer
# 552                 endocrine system disease
# 553                   nervous system disease
# 554             parasitic infectious disease
# 555                   nervous system disease
# 556  developmental disorder of mental health
# 557                                   cancer
# 558                   nervous system disease
# 559                   nervous system disease
# 560              reproductive system disease
#
# [561 rows x 3 columns]

# %%
dir(a)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_call',
#  'act',
#  'adj_mats',
#  'dropout',
#  'edge_type',
#  'issparse',
#  'logging',
#  'name',
#  'num_types',
#  'vars']

# %%
print(tf.ones)
# Out:
# <function ones at 0x7f897514ae60>
