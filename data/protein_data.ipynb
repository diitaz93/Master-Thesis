# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
df = pd.read_csv('proteins.tab',sep='\t')
df.head()
# Out:
#     Entry Cross-reference (GeneID)  \
# 0  Q8N8B7                  170082;
# 1  O75494                   10772;
# 2  Q96L92                   81609;
# 3  Q99598                    7257;
# 4  P49765                    7423;
#
#                                          Beta strand  \
# 0                                                NaN
# 1                                                NaN
# 2  STRAND 41..47;  /evidence="ECO:0000244|PDB:6SA...
# 3  STRAND 109..111;  /evidence="ECO:0000244|PDB:3...
# 4  STRAND 46..55;  /evidence="ECO:0000244|PDB:2C7...
#
#                                                Helix  Length  Toxic dose
# 0                                                NaN     351         NaN
# 1                                                NaN     262         NaN
# 2  HELIX 89..93;  /evidence="ECO:0000244|PDB:6SAK...     541         NaN
# 3  HELIX 34..75;  /evidence="ECO:0000244|PDB:3QB5...     290         NaN
# 4    HELIX 38..45;  /evidence="ECO:0000244|PDB:2C7W"     207         NaN

# %%
del df['Entry']
del df['Toxic dose']
df.rename(columns={'Cross-reference (GeneID)':'GeneID','Beta strand':'n_strands'\
                  ,'Helix':'n_helix'},inplace=True)
df['GeneID'] = df['GeneID'].str.replace(';', '')
df.head()
# Out:
#    GeneID                                          n_strands  \
# 0  170082                                                NaN
# 1   10772                                                NaN
# 2   81609  STRAND 41..47;  /evidence="ECO:0000244|PDB:6SA...
# 3    7257  STRAND 109..111;  /evidence="ECO:0000244|PDB:3...
# 4    7423  STRAND 46..55;  /evidence="ECO:0000244|PDB:2C7...
#
#                                              n_helix  Length
# 0                                                NaN     351
# 1                                                NaN     262
# 2  HELIX 89..93;  /evidence="ECO:0000244|PDB:6SAK...     541
# 3  HELIX 34..75;  /evidence="ECO:0000244|PDB:3QB5...     290
# 4    HELIX 38..45;  /evidence="ECO:0000244|PDB:2C7W"     207

# %% [markdown]
# ### Remove genes with no info about helices or strands and drop useless columns

# %%
beta = df[df['n_strands'].str.contains('evidence',na=False)]
print(len(beta.index))
df = beta[beta['n_helix'].str.contains('evidence',na=False)]
print(len(df.index))
df.head()
# Out:
# 5595
# 5400
#    GeneID                                          n_strands  \
# 2   81609  STRAND 41..47;  /evidence="ECO:0000244|PDB:6SA...
# 3    7257  STRAND 109..111;  /evidence="ECO:0000244|PDB:3...
# 4    7423  STRAND 46..55;  /evidence="ECO:0000244|PDB:2C7...
# 10   6736  STRAND 121..123;  /evidence="ECO:0000244|PDB:6...
# 12    671  STRAND 35..41;  /evidence="ECO:0000244|PDB:1EW...
#
#                                               n_helix  Length
# 2   HELIX 89..93;  /evidence="ECO:0000244|PDB:6SAK...     541
# 3   HELIX 34..75;  /evidence="ECO:0000244|PDB:3QB5...     290
# 4     HELIX 38..45;  /evidence="ECO:0000244|PDB:2C7W"     207
# 10  HELIX 66..79;  /evidence="ECO:0000244|PDB:6EDB...     204
# 12  HELIX 42..60;  /evidence="ECO:0000244|PDB:1EWF...     487

# %% [markdown]
# ### Split Helix and Strand columns

# %%
beta = pd.DataFrame(df.n_strands)
beta = beta['n_strands'].str.split("STRAND", expand = True)
beta.head()
# Out:
#    0                                               1    \
# 2          41..47;  /evidence="ECO:0000244|PDB:6SAK";
# 3          109..111;  /evidence="ECO:0000244|PDB:3QB5"
# 4          46..55;  /evidence="ECO:0000244|PDB:2C7W";
# 10       121..123;  /evidence="ECO:0000244|PDB:6EDB";
# 12         35..41;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                              2    \
# 2    55..62;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                           None
# 4    61..64;  /evidence="ECO:0000244|PDB:2XAC";
# 10   124..126;  /evidence="ECO:0000244|PDB:1HRY"
# 12   68..71;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                              3    \
# 2    68..70;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                           None
# 4    66..81;  /evidence="ECO:0000244|PDB:2C7W";
# 10                                          None
# 12   75..79;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                              4    \
# 2    73..76;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                           None
# 4    83..86;  /evidence="ECO:0000244|PDB:2C7W";
# 10                                          None
# 12   81..93;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                               5    \
# 2     79..84;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                            None
# 4    88..105;  /evidence="ECO:0000244|PDB:2C7W";
# 10                                           None
# 12   97..102;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                6    \
# 2    100..104;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                             None
# 4      108..125;  /evidence="ECO:0000244|PDB:2C7W"
# 10                                            None
# 12   106..126;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                7    \
# 2    125..133;  /evidence="ECO:0000244|PDB:6SAK";
# 3                                             None
# 4                                             None
# 10                                            None
# 12   129..153;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                8    \
# 2    165..175;  /evidence="ECO:0000244|PDB:4HAS";
# 3                                             None
# 4                                             None
# 10                                            None
# 12   158..169;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                9    ...   193   194   195  \
# 2    178..187;  /evidence="ECO:0000244|PDB:4HAS";   ...  None  None  None
# 3                                             None  ...  None  None  None
# 4                                             None  ...  None  None  None
# 10                                            None  ...  None  None  None
# 12   172..176;  /evidence="ECO:0000244|PDB:1EWF";   ...  None  None  None
#
#      196   197   198   199   200   201   202
# 2   None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None
#
# [5 rows x 203 columns]

# %%
alpha = pd.DataFrame(df.n_helix)
alpha = alpha['n_helix'].str.split("HELIX", expand = True)
alpha.head()
# Out:
#    0                                             1    \
# 2        89..93;  /evidence="ECO:0000244|PDB:6SAK";
# 3        34..75;  /evidence="ECO:0000244|PDB:3QB5";
# 4          38..45;  /evidence="ECO:0000244|PDB:2C7W"
# 10       66..79;  /evidence="ECO:0000244|PDB:6EDB";
# 12       42..60;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                2    \
# 2    114..123;  /evidence="ECO:0000244|PDB:6SAK";
# 3     83..108;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10     87..98;  /evidence="ECO:0000244|PDB:6EDB";
# 12   180..182;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                3    \
# 2    197..210;  /evidence="ECO:0000244|PDB:4HAS";
# 3    117..119;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10     103..118;  /evidence="ECO:0000244|PDB:6EDB"
# 12   183..192;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                4    \
# 2    229..246;  /evidence="ECO:0000244|PDB:4HAS";
# 3    121..139;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10                                            None
# 12   194..215;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                5    \
# 2    250..253;  /evidence="ECO:0000244|PDB:4HAS";
# 3    145..150;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10                                            None
# 12   217..221;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                6    \
# 2      256..261;  /evidence="ECO:0000244|PDB:4HAS"
# 3    184..207;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10                                            None
# 12   291..303;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                7    \
# 2                                             None
# 3    213..231;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10                                            None
# 12   313..315;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                8    \
# 2                                             None
# 3    232..234;  /evidence="ECO:0000244|PDB:3QB5";
# 4                                             None
# 10                                            None
# 12   326..330;  /evidence="ECO:0000244|PDB:1EWF";
#
#                                                9    ...   115   116   117  \
# 2                                             None  ...  None  None  None
# 3      237..263;  /evidence="ECO:0000244|PDB:3QB5"  ...  None  None  None
# 4                                             None  ...  None  None  None
# 10                                            None  ...  None  None  None
# 12   336..339;  /evidence="ECO:0000244|PDB:1EWF";   ...  None  None  None
#
#      118   119   120   121   122   123   124
# 2   None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None
#
# [5 rows x 125 columns]

# %% [markdown]
# ### Reeplace columns for the number of elements in the column

# %%
df.loc[:,'n_strands'] = beta.count(axis=1)
df.loc[:,'n_helix'] = alpha.count(axis=1)
df.head()
# Out:
#    GeneID  n_strands  n_helix  Length
# 2   81609         11        7     541
# 3    7257          2       10     290
# 4    7423          7        2     207
# 10   6736          3        4     204
# 12    671         29       13     487

# %%
df.to_csv('proteins.csv',index=False)
