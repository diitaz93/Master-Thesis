# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # New protein Features

# %%
import pandas as pd

# %%
prot = pd.read_csv('../../Thesis_datasets/UniProt/uni_prot.tab',sep = '\t',low_memory=False)
prot.head()
# Out:
#     Entry Cross-reference (GeneID)  Length    Mass  \
# 0  Q8NF67                      NaN     263  31,171
# 1  Q9NPB9                   51554;     350  39,914
# 2  P31937                   11112;     336  35,329
# 3  P61981                    7532;     247  28,303
# 4  O94805                   51412;     426  46,877
#
#                                                Helix  \
# 0                                                NaN
# 1                                                NaN
# 2  HELIX 51..60;  /evidence="ECO:0000244|PDB:2GF2...
# 3  HELIX 4..16;  /evidence="ECO:0000244|PDB:3UZD"...
# 4                                                NaN
#
#                                          Beta strand  \
# 0                                                NaN
# 1                                                NaN
# 2  STRAND 42..45;  /evidence="ECO:0000244|PDB:2GF...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
prot = pd.read_csv('modif_data/new-decagon-genes.csv',sep = ',')
prot.head()
# Out:
#    GeneID  Length   Mass  n_helices  n_strands  n_turns
# 0   11112     336  35329         17         10        4
# 1    7532     247  28303         12          0        4
# 2   51412     426  46877          0          0        0
# 3     125     375  39855         18         22        4
# 4  170572     447  50220          0          0        0

# %%
(prot['Length'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-27ddb9b6f12b> in <module>()
# ----> 1 histogam(prot['Length'])
#
# NameError: name 'histogam' is not defined
